# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.matrix(pd.read_csv("../archive/exoTrain.csv").values)
training_data_y = data[:,0]
training_data_y -=1

# %%
import lightkurve as lk

training_data_x = np.zeros(shape=(len(data),3197))
for i in range(0,len(training_data_x)):
 
    lc = lk.LightCurve(time=range(0,3197), flux=np.array(data[i,1:]).flatten())
    #lc.scatter()
    lc = lc.flatten()
    lc_temp, bool_mask = lc.remove_outliers(return_mask=True)
    lc[bool_mask] = np.nan
    lc = lc.fill_gaps()
    if(len(lc.flux) != 3197):
        med = np.median(lc.flux)
        pad = np.repeat(med, 3197-len(lc.flux))
        test = np.append(lc.flux, pad)
        training_data_x[i, :] = test
    else:
        training_data_x[i, :] = lc.flux
    print(i)
    
    #print(i, len(lc.flux), "/n")
    #lc.to_periodogram("bls", frequency_factor= 1000).plot()
    #lc = lc.fold(period)
    #lc.scatter()
# Out:
# /opt/conda/lib/python3.7/site-packages/lightkurve/lightcurve.py:1048: LightkurveWarning: The light curve appears to be zero-centered (median=1.00e+00 +/- 2.30e+00); `normalize()` will divide the light curve by a value close to zero, which is probably not what you want.
#   LightkurveWarning,
# /opt/conda/lib/python3.7/site-packages/lightkurve/lightcurve.py:1048: LightkurveWarning: The light curve appears to be zero-centered (median=1.00e+00 +/- 3.53e+00); `normalize()` will divide the light curve by a value close to zero, which is probably not what you want.
#   LightkurveWarning,
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# /opt/conda/lib/python3.7/site-packages/lightkurve/lightcurve.py:1048: LightkurveWarning: The light curve appears to be zero-centered (median=9.08e-01 +/- 6.94e+00); `normalize()` will divide the light curve by a value close to zero, which is probably not what you want.
#   LightkurveWarning,
# ...
