# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import pickle

# %%
#normalize X values to help model converge
def normalize(data):
    mean = np.mean(data, axis=0)
    std = np.std(data, axis=0)
    data = (data - mean) / std
    return data

# %%
#retrieve and format data - into labels and examples from the dataset
def features_and_labels(filename_a, filename_b):
    with open(filename_b, 'rb') as f:
        labels = np.load(f).ravel()
    
    data = pd.read_pickle(filename_a)
    #https://stackoverflow.com/questions/22798934/pandas-long-to-wide-reshape-by-two-variables
    data_x = data.pivot(index='id', columns='time', values='FLUX')
    data_x = normalize(data_x)
    data_x = data_x.to_numpy()
    return data_x, labels

# %%
training_data_x, training_data_y = features_and_labels("../Kepler-Train.pkl", "../Labels-Train.npy")
testing_data_x, testing_data_y = features_and_labels("../Kepler-Test.pkl", "../Labels-Test.npy")
print(training_data_x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3997/3874497125.py in <module>
# ----> 1 training_data_x, training_data_y = features_and_labels("../Kepler-TSFreshModels/Kepler-Train.pkl", "../Kepler-TSFreshModels/Labels-Train.npy")
#       2 testing_data_x, testing_data_y = features_and_labels("../Kepler-TSFreshModels/Kepler-Test.pkl", "../Kepler-TSFreshModels/Labels-Test.npy")
#       3 print(training_data_x)
#
# /tmp/ipykernel_3997/1691515684.py in features_and_labels(filename_a, filename_b)
#       2 def features_and_labels(filename_a, filename_b):
#       3     with open(filename_b, 'rb') as f:
# ----> 4         labels = np.load(f).ravel()
#       5
#       6     data = pd.read_pickle(filename_a)
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     442             # Try a pickle
#     443             if not allow_pickle:
# --> 444                 raise ValueError("Cannot load file containing pickled data "
#     445                                  "when allow_pickle=False")
#     446             try:
#
# ValueError: Cannot load file containing pickled data when allow_pickle=False

# %%
DTclassifier = DecisionTreeClassifier()
DTclassifier.fit(training_data_x, training_data_y)

plt.figure(figsize=(20,20))
tree.plot_tree(DTclassifier, fontsize=10, impurity=False, rounded=True)
plt.show()

y_pred = DTclassifier.predict(testing_data_x)
print("Accuracy percentage: ", accuracy_score(testing_data_y, y_pred)*100, "%")
# Out:
# Accuracy percentage:  85.95933926302413 %

# %%
with open('tf-models/decision-tree.pkl','wb') as f:
    pickle.dump(DTclassifier,f)

# %%
RFclassifier = RandomForestClassifier()
RFclassifier.fit(training_data_x, training_data_y)
y_pred = RFclassifier.predict(testing_data_x)
print("Accuracy percentage: ", accuracy_score(testing_data_y, y_pred)*100, "%")
# Out:
# Accuracy percentage:  91.55019059720458 %

# %%
with open('tf-models/random-forest.pkl','wb') as f:
    pickle.dump(RFclassifier,f)
